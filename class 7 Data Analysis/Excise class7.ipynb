# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Define features and target variable
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[features]  # Features
y = df['price']   # Target variable

# Create a pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),          # Step 1: Scale the data
    ('poly', PolynomialFeatures(degree=2)),# Step 2: Perform polynomial transform
    ('regression', LinearRegression())     # Step 3: Fit a linear regression model
])

# Fit the pipeline
pipeline.fit(X, y)

# Make predictions
y_pred = pipeline.predict(X)

# Calculate R^2 score
r2 = r2_score(y, y_pred)
print("R^2 Score:", r2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and 'waterfront' is the column indicating waterfront view
# Replace 'df' and 'waterfront' with the actual names in your dataset

# Create the boxplot
sns.boxplot(x='waterfront', y='price', data=df)

# Add labels and title
plt.xlabel('Waterfront View')
plt.ylabel('Price')
plt.title('Boxplot of Price by Waterfront View')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# Replace 'df' with the name of your DataFrame if it's different

# Create the regression plot
sns.regplot(x='sqft_above', y='price', data=df)

# Add labels and title
plt.xlabel('Sqft Above')
plt.ylabel('Price')
plt.title('Regression Plot of Sqft Above vs. Price')

# Show the plot
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Assuming df is your DataFrame
# Replace 'df' with the name of your DataFrame if it's different

# Define features and target variable
X = df[['sqft_living']]  # Feature
y = df['price']           # Target variable

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Calculate R^2 score
r2 = r2_score(y, y_pred)
print("R^2 Score:", r2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Assuming df is your DataFrame
# Replace 'df' with the name of your DataFrame if it's different

# Define features and target variable
features = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", 
            "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df[features]  # Features
y = df['price']   # Target variable

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Calculate R^2 score
r2 = r2_score(y, y_pred)
print("R^2 Score:", r2)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# Assuming X_train, y_train, X_test, and y_test are your training and test data
# Replace them with your actual training and test data

# Create and fit a Ridge regression object
ridge = Ridge(alpha=0.1)
ridge.fit(X_train, y_train)

# Make predictions on test data
y_pred = ridge.predict(X_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 Score on Test Data:", r2)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# Assuming X_train, y_train, X_test, and y_test are your training and test data
# Replace them with your actual training and test data

# Perform second-order polynomial transform on training data
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)

# Perform second-order polynomial transform on test data
X_test_poly = poly.transform(X_test)

# Create and fit a Ridge regression object
ridge = Ridge(alpha=0.1)
ridge.fit(X_train_poly, y_train)

# Make predictions on test data
y_pred = ridge.predict(X_test_poly)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 Score on Test Data after Polynomial Transform:", r2)
