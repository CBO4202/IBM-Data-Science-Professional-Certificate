# %%
# import pandas library
import pandas as pd

# %%
#Create dataframe from a dictionary
x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'], 
      'Salary':[100000, 80000, 50000, 60000]}
df = pd.DataFrame(x)
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %%
# Create dataframe from csv file
file_name ='addresses.csv'
df = pd.read_csv(file_name, header=None)
df.head()
# Out:
#                0         1                                 2          3    4  \
# 0           John       Doe                 120 jefferson st.  Riverside   NJ
# 1           Jack  McGinnis                      220 hobo Av.      Phila   PA
# 2  John "Da Man"    Repici                 120 Jefferson St.  Riverside   NJ
# 3        Stephen     Tyler  7452 Terrace "At the Plaza" road   SomeTown   SD
# 4            NaN  Blankman                               NaN   SomeTown   SD
#
#        5
# 0   8075
# 1   9119
# 2   8075
# 3  91234
# 4    298

# %%
df.columns=['First','Last','Address' ,'City', 'State','Zip']

# %%
df.head()
# Out:
#            First      Last                           Address       City State  \
# 0           John       Doe                 120 jefferson st.  Riverside    NJ
# 1           Jack  McGinnis                      220 hobo Av.      Phila    PA
# 2  John "Da Man"    Repici                 120 Jefferson St.  Riverside    NJ
# 3        Stephen     Tyler  7452 Terrace "At the Plaza" road   SomeTown    SD
# 4            NaN  Blankman                               NaN   SomeTown    SD
#
#      Zip
# 0   8075
# 1   9119
# 2   8075
# 3  91234
# 4    298

# %%
df.loc[1]
# Out:
# First              Jack
# Last           McGinnis
# Address    220 hobo Av.
# City              Phila
# State                PA
# Zip                9119
# Name: 1, dtype: object

# %%
dfNJ=df[df['State']=='NJ']
print(dfNJ)
# Out:
# Empty DataFrame
# Columns: [First, Last, Address, City, State, Zip]
# Index: []

# %%
df.set_index('State')
# Out:
#                        First      Last                           Address  \
# State
#  NJ                     John       Doe                 120 jefferson st.
#  PA                     Jack  McGinnis                      220 hobo Av.
#  NJ            John "Da Man"    Repici                 120 Jefferson St.
# SD                   Stephen     Tyler  7452 Terrace "At the Plaza" road
#  SD                      NaN  Blankman                               NaN
# CO     Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#               City    Zip
# State
#  NJ      Riverside   8075
#  PA          Phila   9119
#  NJ      Riverside   8075
# SD        SomeTown  91234
#  SD       SomeTown    298
# CO     Desert City    123

# %%
df.head()
# Out:
#            First      Last                           Address       City State  \
# 0           John       Doe                 120 jefferson st.  Riverside    NJ
# 1           Jack  McGinnis                      220 hobo Av.      Phila    PA
# 2  John "Da Man"    Repici                 120 Jefferson St.  Riverside    NJ
# 3        Stephen     Tyler  7452 Terrace "At the Plaza" road   SomeTown    SD
# 4            NaN  Blankman                               NaN   SomeTown    SD
#
#      Zip
# 0   8075
# 1   9119
# 2   8075
# 3  91234
# 4    298

# %%
df.dtypes
# Out:
# First      object
# Last       object
# Address    object
# City       object
# State      object
# Zip         int64
# dtype: object

# %%
#doublr brackets return dataframe, 
#single braket return series
df_name=df[['First','Last']]
df_name.head()
# Out:
#            First      Last
# 0           John       Doe
# 1           Jack  McGinnis
# 2  John "Da Man"    Repici
# 3        Stephen     Tyler
# 4            NaN  Blankman
